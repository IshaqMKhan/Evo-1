# %%
import pickle

file_path = "/home/qxc857/Evo-1/Evo_1/training_data_cache/metaworld_sawyer/Evo1_MetaWorld/chunk-000/episode_000000/97_147.pkl"

# Load the pickle file
with open(file_path, "rb") as f:
    data = pickle.load(f)

# Check what keys are inside
print("Keys in file:", data.keys() if isinstance(data, dict) else type(data))

# Try to access target_action
if isinstance(data, dict) and "target_action" in data:
    print("target_action:", data["target_action"])
else:
    print("target_action not found. Full content:")
    print(data)
# Out:
# Running cells with 'Evo1 (Python 3.10.20)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Evo1 ipykernel --update-deps --force-reinstall'

# %%
conda install -n Evo1 ipykernel --update-deps --force-reinstal
# Out:
# Running cells with 'Evo1 (Python 3.10.20)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Evo1 ipykernel --update-deps --force-reinstall'

# %%
import pprint
pprint.pprint(data)

# %%
print(type(data))
print(len(data))
print(data[0])
